# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("Zomato Dataset.csv")

# %%
data.head(50)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1   0xd987      KOCRES16DEL01                 21.0                      4.7
# 2   0x2784     PUNERES13DEL03                 23.0                      4.7
# 3   0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4   0xdb64      KNPRES14DEL02                 24.0                      4.7
# 5   0x3af3      MUMRES15DEL03                 29.0                      4.5
# 6   0x3aab      MYSRES01DEL01                 35.0                      4.0
# 7   0x689b     PUNERES20DEL01                 33.0                      4.2
# 8   0x6f67      HYDRES14DEL01                 34.0                      4.9
# 9   0xc9cf      KOLRES15DEL03                 21.0                      4.7
# 10  0x36b8     PUNERES19DEL02                 25.0                      4.1
# ...

# %%
data['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny', nan],
#       dtype=object)

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %%
data.shape
# Out:
# (41359, 20)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41359 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           41359 non-null  object
#  1   Delivery_person_ID           41359 non-null  object
#  2   Delivery_person_Age          41359 non-null  float64
#  3   Delivery_person_Ratings      41359 non-null  float64
#  4   Restaurant_latitude          41359 non-null  float64
#  5   Restaurant_longitude         41359 non-null  float64
#  6   Delivery_location_latitude   41359 non-null  float64
#  7   Delivery_location_longitude  41359 non-null  float64
#  8   Order_Date                   41359 non-null  object
#  9   Time_Orderd                  41359 non-null  object
#  10  Time_Order_picked            41359 non-null  object
#  11  Weather_conditions           41359 non-null  object
#  12  Road_traffic_density         41359 non-null  object
# ...

# %%
data["Time_Orderd"] = data["Time_Orderd"].apply(lambda x: (x.replace(":", ",")) )

# %%
data["Time_Orderd"] = data["Time_Orderd"].apply(lambda x: (x.replace(",", ".")) )

# %%
data["Time_Order_picked"] = data["Time_Order_picked"].apply(lambda x: (x.replace(":", ".")) )

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41359 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           41359 non-null  object
#  1   Delivery_person_ID           41359 non-null  object
#  2   Delivery_person_Age          41359 non-null  float64
#  3   Delivery_person_Ratings      41359 non-null  float64
#  4   Restaurant_latitude          41359 non-null  float64
#  5   Restaurant_longitude         41359 non-null  float64
#  6   Delivery_location_latitude   41359 non-null  float64
#  7   Delivery_location_longitude  41359 non-null  float64
#  8   Order_Date                   41359 non-null  object
#  9   Time_Orderd                  41359 non-null  object
#  10  Time_Order_picked            41359 non-null  object
#  11  Weather_conditions           41359 non-null  object
#  12  Road_traffic_density         41359 non-null  object
# ...

# %%
data.shape
# Out:
# (41359, 20)

# %%
convert_dict = {
    'Time_Orderd' : float
#     'Time_Order_picked' : float,
}

data = data.astype(convert_dict)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41359 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           41359 non-null  object
#  1   Delivery_person_ID           41359 non-null  object
#  2   Delivery_person_Age          41359 non-null  float64
#  3   Delivery_person_Ratings      41359 non-null  float64
#  4   Restaurant_latitude          41359 non-null  float64
#  5   Restaurant_longitude         41359 non-null  float64
#  6   Delivery_location_latitude   41359 non-null  float64
#  7   Delivery_location_longitude  41359 non-null  float64
#  8   Order_Date                   41359 non-null  object
#  9   Time_Orderd                  41359 non-null  float64
#  10  Time_Order_picked            41359 non-null  object
#  11  Weather_conditions           41359 non-null  object
#  12  Road_traffic_density         41359 non-null  object
# ...

# %%
data1 = data.drop(columns=['ID', 'Delivery_person_ID'], axis=1)
data1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022        21.55             22.10
# 1                    76.347589  13-02-2022        14.55             15.05
# ...

# %%
data1["City"].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41359 entries, 0 to 45583
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          41359 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          41359 non-null  float64
#  3   Restaurant_longitude         41359 non-null  float64
#  4   Delivery_location_latitude   41359 non-null  float64
#  5   Delivery_location_longitude  41359 non-null  float64
#  6   Order_Date                   41359 non-null  object
#  7   Time_Orderd                  41359 non-null  float64
#  8   Time_Order_picked            41359 non-null  object
#  9   Weather_conditions           41359 non-null  object
#  10  Road_traffic_density         41359 non-null  object
#  11  Vehicle_condition            41359 non-null  int64
#  12  Type_of_order                41359 non-null  object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Lab = LabelEncoder()
data1['Weather_conditions'] = Lab.fit_transform(data1["Weather_conditions"])
data1['Road_traffic_density'] = Lab.fit_transform(data1['Road_traffic_density'])
data1["Type_of_order"] = Lab.fit_transform(data1['Type_of_order'])
data1["Type_of_vehicle"] = Lab.fit_transform(data1['Type_of_vehicle'])
data1['City'] = Lab.fit_transform(data1['City'])
data1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022        21.55             22.10
# 1                    76.347589  13-02-2022        14.55             15.05
# ...

# %%
data1['Festival'] = Lab.fit_transform(data1['Festival'])
data1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022        21.55             22.10
# 1                    76.347589  13-02-2022        14.55             15.05
# ...

# %%
data1 = data1.drop(45581)

# %%
data1.Time_Order_picked.unique()
# Out:
# array(['22.10', '15.05', '17.40', '09.30', '20.05', '20.35', '15.10',
#        '20.40', '21.30', '20.25', '22.45', '08.30', '19.45', '12.30',
#        '18.50', '23.30', '21.35', '23.45', '22.50', '22.40', '23.35',
#        '13.40', '21.45', '19.10', '14.25', '11.10', '09.55', '08.55',
#        '23.10', '17.30', '19.50', '19.25', '0.458333333', '19.15',
#        '16.55', '11.40', '15.15', '22.55', '22.25', '20.55', '23.05',
#        '0.75', '0.958333333', '20.50', '20.20', '22.35', '0.916666667',
#        '23.55', '15.40', '10.30', '0.875', '10.50', '16.05', '20.15',
#        '12.15', '15.45', '22.15', '10.45', '24.05.00', '21.25', '12.45',
#        '21.15', '18.20', '18.25', '11.50', '12.50', '10.55', '21.40',
#        '10.20', '17.55', '23.50', '12.55', '24.10.00', '10.40', '0.375',
#        '20.45', '0.833333333', '23.15', '18.35', '22.20', '21.05',
#        '0.708333333', '24.15.00', '21.20', '14.35', '10.25', '09.05',
# ...

# %%
invalid_time_mask = data1['Time_Order_picked'].str.contains(r'^24\.\d{2}\.\d{2}$', regex=True)

# Identify the row numbers with invalid time formats
problematic_rows = data1[invalid_time_mask].index.tolist()

# Display the problematic rows
print("Row numbers with invalid time formats:")
print(problematic_rows)
# Out:
# Row numbers with invalid time formats:
# ...

# %%
data1['Time_Order_picked'][27777]
# Out:
# '24.15.00'

# %%
data1['Time_Order_picked'] = data1['Time_Order_picked'].apply(lambda x: x[:-3] if x.endswith('.00') else x)

# %%
data1['Time_Order_picked'].astype(float)
# Out:
# 0        22.10
# 1        15.05
# 2        17.40
# 3         9.30
# 4        20.05
#          ...
# 45578    21.55
# 45579    11.45
# 45580    20.10
# 45582    13.40
# 45583    17.15
# Name: Time_Order_picked, Length: 41358, dtype: float64

# %%
data.Festival.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41358 entries, 0 to 45583
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          41358 non-null  float64
#  1   Delivery_person_Ratings      41358 non-null  float64
#  2   Restaurant_latitude          41358 non-null  float64
#  3   Restaurant_longitude         41358 non-null  float64
#  4   Delivery_location_latitude   41358 non-null  float64
#  5   Delivery_location_longitude  41358 non-null  float64
#  6   Order_Date                   41358 non-null  object
#  7   Time_Orderd                  41358 non-null  float64
#  8   Time_Order_picked            41358 non-null  object
#  9   Weather_conditions           41358 non-null  int32
#  10  Road_traffic_density         41358 non-null  int32
#  11  Vehicle_condition            41358 non-null  int64
#  12  Type_of_order                41358 non-null  int32
# ...

# %%
# Convert 'Date' column to datetime format
data1['Order_Date'] = pd.to_datetime(data1['Order_Date'], format='%d-%m-%Y')

# Extract features: day, month, year
data1['Day'] = data1['Order_Date'].dt.day
data1['Month'] = data1['Order_Date'].dt.month
data1['Year'] = data1['Order_Date'].dt.year

# Drop the original 'Date' column if not needed
data2 = data1.drop(columns=['Order_Date'])

# Display the preprocessed DataFrame
print("Preprocessed DataFrame:")
data2.head()
# Out:
# Preprocessed DataFrame:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd Time_Order_picked  \
# 0                    78.116106        21.55             22.10
# 1                    76.347589        14.55             15.05
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
plt.hist(data2['Time_Orderd'])
# Out:
# (array([ 3834.,     0.,     0.,  3311.,  3337.,  1592.,  1781.,  7857.,
#          9127., 10519.]),
#  array([ 0.375 ,  2.6925,  5.01  ,  7.3275,  9.645 , 11.9625, 14.28  ,
#         16.5975, 18.915 , 21.2325, 23.55  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(data2['Delivery_location_longitude'], data2['Delivery_location_latitude'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41358 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          41358 non-null  float64
#  1   Delivery_person_Ratings      41358 non-null  float64
#  2   Restaurant_latitude          41358 non-null  float64
#  3   Restaurant_longitude         41358 non-null  float64
#  4   Delivery_location_latitude   41358 non-null  float64
#  5   Delivery_location_longitude  41358 non-null  float64
#  6   Time_Orderd                  41358 non-null  float64
#  7   Time_Order_picked            41358 non-null  object
#  8   Weather_conditions           41358 non-null  int32
#  9   Road_traffic_density         41358 non-null  int32
#  10  Vehicle_condition            41358 non-null  int64
#  11  Type_of_order                41358 non-null  int32
#  12  Type_of_vehicle              41358 non-null  int32
# ...

# %%
data2['Time_Order_picked'] = data2["Time_Order_picked"].astype(float)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41358 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          41358 non-null  float64
#  1   Delivery_person_Ratings      41358 non-null  float64
#  2   Restaurant_latitude          41358 non-null  float64
#  3   Restaurant_longitude         41358 non-null  float64
#  4   Delivery_location_latitude   41358 non-null  float64
#  5   Delivery_location_longitude  41358 non-null  float64
#  6   Time_Orderd                  41358 non-null  float64
#  7   Time_Order_picked            41358 non-null  float64
#  8   Weather_conditions           41358 non-null  int32
#  9   Road_traffic_density         41358 non-null  int32
#  10  Vehicle_condition            41358 non-null  int64
#  11  Type_of_order                41358 non-null  int32
#  12  Type_of_vehicle              41358 non-null  int32
# ...

# %%
data2 = data2.rename(columns={'Time_taken (min)':'Time_taken(min)'})

# %%
data2.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd  Time_Order_picked  \
# 0                    78.116106        21.55              22.10
# 1                    76.347589        14.55              15.05
# ...

# %%
X = data2.drop(columns=["Time_taken(min)"])
X.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd  Time_Order_picked  \
# 0                    78.116106        21.55              22.10
# 1                    76.347589        14.55              15.05
# ...

# %%
plt.figure(figsize=(20,15))
plt.bar(data2['Delivery_person_Age'], data2['Time_taken(min)'])
plt.title("Delivery Person Age")
# Out:
# Text(0.5, 1.0, 'Delivery Person Age')

# %%
y = data2["Time_taken(min)"]
y.head()
# Out:
# 0    46
# 1    23
# 2    21
# 3    20
# 4    41
# Name: Time_taken(min), dtype: int64

# %%
X.shape,y.shape
# Out:
# ((41358, 19), (41358,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
x_train.shape
# Out:
# (31018, 19)

# %%
y_train.shape
# Out:
# (31018,)

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor()

# %%
DT.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# y_pred = DT.predict(x_test)
y_tred = DT.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_tred)
# Out:
# 0.5349743401864857

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()

# %%
gb.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gb.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean = mean_absolute_error(y_pred, y_test)

# %%
mean
# Out:
# 3.9154738600262067

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.718538675045244
